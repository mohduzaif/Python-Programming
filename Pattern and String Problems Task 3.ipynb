# %% [markdown]
# #### Problem 1 - Print the following pattern. Write a program to use for loop to print the following reverse number pattern.

# %%
# 5 4 3 2 1 
# 4 3 2 1 
# 3 2 1 
# 2 1 
# 1

n = int(input('Enter the value of n : '))

for i in range(n, 0, -1): 
    for j in range(i, 0, -1): 
        print(j, end=' ')
    print()

# %% [markdown]
# ####  Problem 2: Print the following pattern.

# %%
# * 
# * * 
# * * * 
# * * * * 
# * * * * * 
# * * * * 
# * * * 
# * * 
# *

n = int(input('Enter the value of n : ')) 

for i in range(1, n + 1): 
    for j in range(1, i + 1):
        print('*', end='')
    print()

for i in range(n, 0, -1): 
    for j in range(i, 0, -1):
        print('*', end='')
    print()

# %% [markdown]
# #### Problem 3:Write a program to pring the following pattern

# %%
#     *
#   * * *
# * * * * *

# %% [markdown]
# #### Problem 4:Write a program to print the following pattern.

# %%
# 1

# 2 1

# 3 2 1

# 4 3 2 1

# 5 4 3 2 1

n = int(input('Enter the value of n : ')) 

for i in range(1, n+1): 
    for j in range(i, 0, -1): 
        print(j, end=' ')
    print()

# %% [markdown]
# #### Problem 5: Write a Python Program to Find the Sum of the Series till the nth term:
# 1 + x^2/2 + x^3/3 + … x^n/n,
#
# n will be provided by the user

# %%
n = int(input('Enter the value of n : '))  
x = int(input('Enter the value of x : '))

sum_of_sequence = 1
print('1', end='')
for i in range(2, n + 1): 
    print(' + {}^{}/{}'.format(x, i, i), end='')
    sum_of_sequence += x**i/i 
print()
print(sum_of_sequence)

# %% [markdown]
# #### Problem 6: The natural logarithm can be approximated by the following series.

# %% [markdown]
# ![image.png](attachment:6048c90e-eb4a-4f0f-9454-433d50075e20.png)
# If x is input through the keyboard, write a program to calculate the sum of the first seven terms of this series.

# %%
x = int(input('Enter the value of x : ')) 
n = 7

sum_of_sequence = 0
for i in range(1, n + 1):
    sum_of_sequence += (1 / i) * ((x - 1) / x)**i

print(sum_of_sequence)

# %% [markdown]
# #### Problem 7 - Find the sum of the series upto n terms.
# Write a program to calculate the sum of series up to n term. For example, if n =5 the series will become 2 + 22 + 222 + 2222 + 22222 = 24690. Take the user input and then calculate. And the output style should match which is given in the example.

# %%
n = int(input('Enter the value of n : '))  

x = 0
sum_of_sequence = 0
for i in range(1, n + 1): 
    x = x * 10 + 2
    sum_of_sequence += x 

print(sum_of_sequence)

# %% [markdown]
# #### Problem 8: Write a program to print all the unique combinations of 1,2,3 and 4.

# %% [markdown]
# 1 2 3 4
#
# 1 2 4 3
#
# 1 3 2 4
#
# 1 3 4 2
#
# . . . .
#
# . . . .
#
#
# and so on

# %%
for i in range(1, 5):
    for j in range(1, 5): 
        for k in range(1, 5): 
            for l in range(1, 5): 
                print(1, j, k, l)

# %% [markdown]
# #### Problem 9: Write a program that will take a decimal number as input and prints out the binary equivalent of the number.

# %%
n = int(input('Enter the number : '))

result = ''

while n != 0: 
    rem = n % 2
    n = n // 2
    result = str(rem) + result

print(result)
print(type(result))

# %% [markdown]
# #### `Problem 10` : Write a program that will take 2 numbers as input and prints the LCM and HCF of those 2 numbers

# %%
number1 = int(input('Enter the first number : ')) 
number2 = int(input('Enter the second number : '))

number1 = max(number1, number2)
number2 = min(number1, number2)

# find the HCF of the given two numbers. 
while True: 
    remainder = number1 % number2
    if remainder == 0: 
        print('HCF of given two numbers is : ', number2)
        break
    number1 = number2
    number2 = remainder


# find the LCM of the given two numbers. 
i = number1
while True:
    if i % number2 == 0:
        print('LCM is : ', i) 
        break
    i += number1

# %% [markdown]
# #### `Problem 11 :` Create Short Form from initial character.
#
# Given a string create short form of the string from Initial character. Short form should be capitalised.

# %%
# Example : Data science mentorship program   ---->  DSMP

s = input('Enter the String : ')

list = []
list.append(s[0])

for index in range(0, len(s)-1): 
    if s[index] == ' ':
        list.append(s[index + 1].upper())

print(''.join(list))

# %% [markdown]
# #### `Problem 12 :` Append second string in the middle of first string.

# %%
# INPUT : 
    # campusx
    # data
# OUTPUT : 
    # camdatapusx

s = input('Enter the String : ')
merged_string = input('Enter the merged String : ')
middle = len(s) // 2

result = ''

result = result + s[ : middle]
result = result + merged_string
result = result + s[middle : ]

print(result)

# %% [markdown]
# #### `Problem 13 :` Given string contains a combination of the lower and upper case letters. Write a program to arrange the characters of a string so that all lowercase letters should come first.

# %%
# str1 = PyNaTive
# OUTPUT : yaivePNT

str1 = input('Enter the String : ')

lower_case = ''
upper_case = ''

result = ''

for ch in str1: 
    if ch >= 'A' and ch <= 'Z': 
        upper_case += ch 
    else: 
        lower_case += ch 
    
result = lower_case + upper_case
print(result)

# %% [markdown]
# #### `Problem 14 :` Take a alphanumeric string input and print the sum and average of the digits that appear in the string, ignoring all other characters.

# %%
# INPUT : hel123O4every093 

str1 = input('Enter the String : ')

digit = ''
for ch in str1: 
    if ch >= '0' and ch <= '9': 
        digit += ch 

print(digit)

sum = 0
for ch in digit: 
    sum += int(ch) 
print('Sum is : ', sum)
print('Average is : ', sum / len(digit))
